# %% [markdown]
# # 2_PLD_Experiment_Design

# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ['ETS_TOOLKIT'] = 'qt'
import glob
import numpy as np
# from mayavi import mlab
import matplotlib.pyplot as plt
from plume_learn.plume_analyzer.analyze_function import load_plumes_and_align

from m3util.viz.layout import layout_fig, layout_subfigures_inches
from m3util.viz.text import labelfigs, add_text_to_figure
from m3util.viz.lines import draw_lines
# from afm_learn.drawing_3d import sphere_to_surface, draw_box
TabRed = '#E41A1C'
plume_recording_root = 'D:/SRO_STO-Data/SRO_plumes/plume_recordings/'
coords_root = '../data/Plumes/frame_normalize_dataset/'
output_root = '../data/Plumes/plume_metrics/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Target and Plume View

# %%
ds_name, ds_id = 'Sample 3', 'YG067'
file_path = plume_recording_root + 'YG067_YichenGuo_09122024.h5'

frame_view_index = 2
plumes, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=frame_view_index)
fig, axes = layout_fig(2, 2, figsize=(8,4), layout='tight')
axes[0].imshow(frame_view)
axes[0].set_title('Frame view')
axes[1].imshow(plumes[2, 8])
axes[1].set_title('Plume view')
plt.show()
# Out:
# Available datasets: ['1-SrRuO3', '1-SrRuO3_Pre']

# %%
plt.imshow(frame_view/2 + plumes[2, 8]/2)
plt.axis('off')
plt.tight_layout()
plt.savefig('../figures/1_YG067_plume_setup.png', bbox_inches='tight', dpi=600)
plt.savefig('../figures/1_YG067_plume_setup.svg', bbox_inches='tight', dpi=600)
plt.show()

# %%
ds_name, ds_id = 'Sample 5', 'YG069'
file_path = plume_recording_root + 'YG069_YichenGuo_09152024.h5'

frame_view_index = 2
plumes, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=frame_view_index)
fig, axes = layout_fig(2, 2, figsize=(8,4), layout='tight')
axes[0].imshow(frame_view)
axes[0].set_title('Frame view')
axes[1].imshow(plumes[2, 8])
axes[1].set_title('Plume view')
plt.show()
# Out:
# Available datasets: ['1-SrRuO3', '1-SrRuO3_Pre']

# %%
plt.imshow(frame_view/2 + plumes[2, 8]/2)
plt.axis('off')
plt.tight_layout()
plt.savefig('../figures/1_YG069_plume_setup.png', bbox_inches='tight', dpi=600)
plt.savefig('../figures/1_YG069_plume_setup.svg', bbox_inches='tight', dpi=600)
plt.show()

# %% [markdown]
# ## 2. PLD Setup, Chamber View, Target Surface and Plume Views

# %%
img = plt.imread('../figures/3-Experiment_Design_target.png')
fig, ax = layout_fig(1, 1, figsize=(8, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = plt.imread('../figures/1_Experiment_Design_target-01.png')

fig, ax = layout_fig(1, 1, figsize=(8, 8))
plt.imshow(img)
plt.axis('off')

label_size = 15
labelfigs(ax, 0, style='bw', loc='tr', inset_fraction=(0.1, 0.2), size=label_size)
labelfigs(ax, 1, style='bw', loc='bl', inset_fraction=(0.388, 0.20), size=label_size)
labelfigs(ax, 2, style='bw', loc='br', inset_fraction=(0.32, 0.4), size=label_size)
labelfigs(ax, 3, style='bw', loc='br', inset_fraction=(0.378, 0.035), size=label_size)


plt.savefig('../figures/1_Experiment_Design_target_labeled.png', dpi=1000)
plt.savefig('../figures/1_Experiment_Design_target_labeled.svg', dpi=1000)
plt.show()

# %% [markdown]
# Fig. 1 Pulsed laser deposition setup with plume recording camera, and experiment design. a

# %%
img = plt.imread('../figures/1_PLD_Setup_and_Experiment_Design.png')

fig, ax = layout_fig(1, 1, figsize=(8, 8))
plt.imshow(img)
plt.axis('off')

label_size = 15
text_size = 10
add_text_to_figure(fig, 'Plume Camera', (0.5, 7.5), fontsize=text_size)
path_effects=[plt.matplotlib.patheffects.withStroke(linewidth=3, foreground='white')]
add_text_to_figure(fig, 'Viewing Angle=45°', (2, 4.8), fontsize=text_size, color=TabRed, path_effects=path_effects)

labelfigs(ax, 0, style='bw', loc='tr',inset_fraction=(0.1, 0.2), size=label_size)

labelfigs(ax, 1, style='bw', loc='bl',inset_fraction=(0.3, 0.05), size=label_size)
add_text_to_figure(fig, 'Target', (0.55, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (0.65, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (0.65, 0.3), fontsize=text_size)

labelfigs(ax, 2, style='bw', loc='bl',inset_fraction=(0.3, 0.25), size=label_size)
add_text_to_figure(fig, 'Target', (2.15, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (2.3, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (2.3, 0.3), fontsize=text_size)

labelfigs(ax, 3, style='bw', loc='bl',inset_fraction=(0.3, 0.45), size=label_size)
add_text_to_figure(fig, 'Target', (3.75, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (3.85, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (3.85, 0.3), fontsize=text_size)

labelfigs(ax, 4, style='bw', loc='bl',inset_fraction=(0.3, 0.65), size=label_size)
add_text_to_figure(fig, 'Target', (5.35, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (5.45, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (5.45, 0.3), fontsize=text_size)

labelfigs(ax, 5, style='bw', loc='bl',inset_fraction=(0.3, 0.85), size=label_size)
add_text_to_figure(fig, 'Target', (6.95, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (7.12, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (7.1, 0.3), fontsize=text_size)

# plt.savefig('../figures/1_PLD_Setup_and_Experiment_Design_labeled.png', dpi=1000)
plt.show()

# %% [markdown]
# ### 1.1 Summary plot

# %%
fig.text(
    text_position_relative[0], 
    text_position_relative[1], 
    text, 
    fontsize=20, 
    color=halo_color, 
    weight='bold',  # Optional to make the halo thicker
    path_effects=[plt.matplotlib.patheffects.withStroke(linewidth=halo_width, foreground=halo_color)],
)

# %%
img = plt.imread('../figures/1_PLD_Setup_and_Experiment_Design.png')

fig, ax = layout_fig(1, 1, figsize=(8, 8))
plt.imshow(img)
plt.axis('off')

label_size = 15
text_size = 10
add_text_to_figure(fig, 'Plume Camera', (0.5, 7.5), fontsize=text_size)
path_effects=[plt.matplotlib.patheffects.withStroke(linewidth=3, foreground='white')]
add_text_to_figure(fig, 'Viewing Angle=45°', (2, 4.8), fontsize=text_size, color=TabRed, path_effects=path_effects)

labelfigs(ax, 0, style='bw', loc='tr',inset_fraction=(0.1, 0.2), size=label_size)

labelfigs(ax, 1, style='bw', loc='bl',inset_fraction=(0.3, 0.05), size=label_size)
add_text_to_figure(fig, 'Target', (0.55, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (0.65, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (0.65, 0.3), fontsize=text_size)

labelfigs(ax, 2, style='bw', loc='bl',inset_fraction=(0.3, 0.25), size=label_size)
add_text_to_figure(fig, 'Target', (2.15, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (2.3, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (2.3, 0.3), fontsize=text_size)

labelfigs(ax, 3, style='bw', loc='bl',inset_fraction=(0.3, 0.45), size=label_size)
add_text_to_figure(fig, 'Target', (3.75, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (3.85, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (3.85, 0.3), fontsize=text_size)

labelfigs(ax, 4, style='bw', loc='bl',inset_fraction=(0.3, 0.65), size=label_size)
add_text_to_figure(fig, 'Target', (5.35, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (5.45, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (5.45, 0.3), fontsize=text_size)

labelfigs(ax, 5, style='bw', loc='bl',inset_fraction=(0.3, 0.85), size=label_size)
add_text_to_figure(fig, 'Target', (6.95, 1.75), fontsize=text_size)
add_text_to_figure(fig, 'SRO', (7.12, 0.75), fontsize=text_size)
add_text_to_figure(fig, 'STO', (7.1, 0.3), fontsize=text_size)

# plt.savefig('../figures/1_PLD_Setup_and_Experiment_Design_labeled.png', dpi=1000)
plt.show()

# %% [markdown]
# ### 1.2 Draw the 3d diagram for the SRO/STO heterostructure

# %%
mlab.figure(size = (1024,768), bgcolor = (1,1,1), fgcolor = (146/255,197/255,222/255))
draw_box(xrange=(0, 25), yrange=(0, 25), zrange=(2, 4), color=(153/255,216/255,201/255))
draw_box(xrange=(0, 30), yrange=(0, 30), zrange=(0, 2), color=(229/255,245/255,249/255))
mlab.savefig('../figures/1_SRO_STO_3D_drawing.png')
mlab.show()

# %%
subfigures_dict = {
    'pld_setup': {'position': [0.1, 1.6, 7.9, 5],
                'skip_margin': True,
                'right': False},  
    'target_1': {'position': [0.1, 0, 1.5, 1.2],
                'skip_margin': True,
                'right': False},  
    'target_2': {'position': [1.65, 0, 1.5, 1.2],
                'skip_margin': True,
                'right': False},  
    'target_3': {'position': [3.2, 0, 1.5, 1.2],
                'skip_margin': True,
                'right': False},  
    'target_4': {'position': [4.75, 0, 1.5, 1.2],
                'skip_margin': True,
                'right': False},  
    'target_5': {'position': [6.3, 0, 1.5, 1.2],
                'skip_margin': True,
                'right': False}
}
fig, axes_dict = layout_subfigures_inches((8, 6), subfigures_dict, margin_pts=20)
for ax in axes_dict.values():
    ax.axis('off')
    
pld_setup = plt.imread('../figures/1_PLD_Setup.png')
ax = axes_dict['pld_setup']
ax.imshow(pld_setup)
ax.set_title('PLD Setup', fontsize=12)

target_files = glob.glob('../figures/1_target_drawing_shade*.png')
for file, (name, ax) in zip(target_files, list(axes_dict.items())[1:]):
    img = plt.imread(file)
    ax.imshow(img)
    ax.set_title(name, fontsize=12)
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yig319\AppData\Local\Temp\ipykernel_21972\2128679046.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Fig. 1 Pulsed laser deposition setup with plume recording camera.
